# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Описание данных:</a></span></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Импорт-библиотек-и-чтение-фалов." data-toc-modified-id="Импорт-библиотек-и-чтение-фалов.-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Импорт библиотек и чтение фалов.</a></span></li><li><span><a href="#Ознакомимся-с-таблицей." data-toc-modified-id="Ознакомимся-с-таблицей.-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Ознакомимся с таблицей.</a></span></li><li><span><a href="#Детально-ознакомимся-с-столбцами" data-toc-modified-id="Детально-ознакомимся-с-столбцами-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Детально ознакомимся с столбцами</a></span><ul class="toc-item"><li><span><a href="#Возможные-дубликаты-в-locality_name" data-toc-modified-id="Возможные-дубликаты-в-locality_name-1.0.3.1"><span class="toc-item-num">1.0.3.1&nbsp;&nbsp;</span>Возможные дубликаты в locality_name</a></span></li><li><span><a href="#Проверим-&quot;is_apartment&quot;" data-toc-modified-id="Проверим-&quot;is_apartment&quot;-1.0.3.2"><span class="toc-item-num">1.0.3.2&nbsp;&nbsp;</span>Проверим "is_apartment"</a></span></li><li><span><a href="#Проверим-столбец-ceiling_height" data-toc-modified-id="Проверим-столбец-ceiling_height-1.0.3.3"><span class="toc-item-num">1.0.3.3&nbsp;&nbsp;</span>Проверим столбец ceiling_height</a></span></li><li><span><a href="#Столбец-days_exposition" data-toc-modified-id="Столбец-days_exposition-1.0.3.4"><span class="toc-item-num">1.0.3.4&nbsp;&nbsp;</span>Столбец days_exposition</a></span></li><li><span><a href="#Столбец-rooms" data-toc-modified-id="Столбец-rooms-1.0.3.5"><span class="toc-item-num">1.0.3.5&nbsp;&nbsp;</span>Столбец rooms</a></span></li><li><span><a href="#Столбец-cityCenters_nearest" data-toc-modified-id="Столбец-cityCenters_nearest-1.0.3.6"><span class="toc-item-num">1.0.3.6&nbsp;&nbsp;</span>Столбец cityCenters_nearest</a></span></li><li><span><a href="#Столбец-floors_total-и-locality_name" data-toc-modified-id="Столбец-floors_total-и-locality_name-1.0.3.7"><span class="toc-item-num">1.0.3.7&nbsp;&nbsp;</span>Столбец floors_total и locality_name</a></span></li></ul></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучим-параметры:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Изучим-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучим параметры: площадь, цена, число комнат, высота потолков.</a></span><ul class="toc-item"><li><span><a href="#Автоматизируем-процесс,-напишем-функции" data-toc-modified-id="Автоматизируем-процесс,-напишем-функции-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Автоматизируем процесс, напишем функции</a></span></li><li><span><a href="#Площадь-(total_area)" data-toc-modified-id="Площадь-(total_area)-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Площадь (total_area)</a></span></li><li><span><a href="#Цена-(last_price)" data-toc-modified-id="Цена-(last_price)-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Цена (last_price)</a></span></li><li><span><a href="#Число-комнат-(rooms)" data-toc-modified-id="Число-комнат-(rooms)-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Число комнат (rooms)</a></span></li><li><span><a href="#Высота-потолков-(ceiling_height)" data-toc-modified-id="Высота-потолков-(ceiling_height)-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Высота потолков (ceiling_height)</a></span></li></ul></li><li><span><a href="#Изучим-время-продажи-квартиры:" data-toc-modified-id="Изучим-время-продажи-квартиры:-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучим время продажи квартиры:</a></span><ul class="toc-item"><li><span><a href="#Применим-фильтрацию:" data-toc-modified-id="Применим-фильтрацию:-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Применим фильтрацию:</a></span></li></ul></li><li><span><a href="#Проведём-изучение:" data-toc-modified-id="Проведём-изучение:-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Проведём изучение:</a></span><ul class="toc-item"><li><span><a href="#Цена-от-площади,-числа-комнат,-удалённости-от-центра:" data-toc-modified-id="Цена-от-площади,-числа-комнат,-удалённости-от-центра:-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Цена от площади, числа комнат, удалённости от центра:</a></span></li><li><span><a href="#Цены-от-того,-на-каком-этаже-расположена-квартира:" data-toc-modified-id="Цены-от-того,-на-каком-этаже-расположена-квартира:-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Цены от того, на каком этаже расположена квартира:</a></span></li><li><span><a href="#Зависимость-от-даты-размещения:-дня-недели,-месяца-и-года:" data-toc-modified-id="Зависимость-от-даты-размещения:-дня-недели,-месяца-и-года:-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Зависимость от даты размещения: дня недели, месяца и года:</a></span></li></ul></li><li><span><a href="#Изучим-населённые-пункты:" data-toc-modified-id="Изучим-населённые-пункты:-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Изучим населённые пункты:</a></span></li><li><span><a href="#Изучим-предложения-квартир:" data-toc-modified-id="Изучим-предложения-квартир:-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Изучим предложения квартир:</a></span></li><li><span><a href="#Изучим-центральный-район:" data-toc-modified-id="Изучим-центральный-район:-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучим центральный район:</a></span><ul class="toc-item"><li><span><a href="#Функции-и-обозначения:" data-toc-modified-id="Функции-и-обозначения:-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Функции и обозначения:</a></span></li><li><span><a href="#Площадь-в-центре:" data-toc-modified-id="Площадь-в-центре:-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>Площадь в центре:</a></span></li><li><span><a href="#Цена-в-центре:" data-toc-modified-id="Цена-в-центре:-4.6.3"><span class="toc-item-num">4.6.3&nbsp;&nbsp;</span>Цена в центре:</a></span></li><li><span><a href="#Число-комнат-в-центре:" data-toc-modified-id="Число-комнат-в-центре:-4.6.4"><span class="toc-item-num">4.6.4&nbsp;&nbsp;</span>Число комнат в центре:</a></span></li><li><span><a href="#Высота-потолков-в-центре:" data-toc-modified-id="Высота-потолков-в-центре:-4.6.5"><span class="toc-item-num">4.6.5&nbsp;&nbsp;</span>Высота потолков в центре:</a></span></li><li><span><a href="#Выделим-факторы,-которые-влияют-на-стоимость-квартиры:" data-toc-modified-id="Выделим-факторы,-которые-влияют-на-стоимость-квартиры:-4.6.6"><span class="toc-item-num">4.6.6&nbsp;&nbsp;</span>Выделим факторы, которые влияют на стоимость квартиры:</a></span><ul class="toc-item"><li><span><a href="#Число-комнат:" data-toc-modified-id="Число-комнат:-4.6.6.1"><span class="toc-item-num">4.6.6.1&nbsp;&nbsp;</span>Число комнат:</a></span></li><li><span><a href="#Этаж:" data-toc-modified-id="Этаж:-4.6.6.2"><span class="toc-item-num">4.6.6.2&nbsp;&nbsp;</span>Этаж:</a></span></li><li><span><a href="#Удалённость-от-центра." data-toc-modified-id="Удалённость-от-центра.-4.6.6.3"><span class="toc-item-num">4.6.6.3&nbsp;&nbsp;</span>Удалённость от центра.</a></span></li><li><span><a href="#Зависимость-от-даты-размещения:" data-toc-modified-id="Зависимость-от-даты-размещения:-4.6.6.4"><span class="toc-item-num">4.6.6.4&nbsp;&nbsp;</span>Зависимость от даты размещения:</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Наша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### Описание данных:
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# #### Импорт библиотек и чтение фалов.

# %%
# Импорт библиотек и доп. опции.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)

# %%
# Чтение файлов:
try:
    data = pd.read_csv(
        '/home/saxofon/Документы/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv(
        '/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# #### Ознакомимся с таблицей.

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0        51.00      8          NaN   False
# ...

# %%
data.shape
# Out:
# (23699, 22)

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# _cityCenters_nearest стоит переименовать, остальные столбцы в порядке._

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# #### Детально ознакомимся с столбцами

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# _Напишем функцию для удобства работы:_

# %%
# функция, получающая на вход название столбца, и возвращающая % пропущенных значений.
def nan_ratio(column):
    return print('Пропущено {:.1%}'. format(data[column].isna().value_counts()[1] / len(data), 2) + ' значений')

# %% [markdown]
# ##### Возможные дубликаты в locality_name

# %%
data.groupby('locality_name').size().to_dict()
# Out:
# {'Бокситогорск': 16,
#  'Волосово': 36,
#  'Волхов': 111,
#  'Всеволожск': 398,
#  'Выборг': 237,
#  'Высоцк': 4,
#  'Гатчина': 307,
#  'Зеленогорск': 24,
#  'Ивангород': 28,
#  'Каменногорск': 13,
#  'Кингисепп': 104,
#  'Кириши': 125,
#  'Кировск': 84,
#  'Колпино': 338,
#  'Коммунар': 89,
#  'Красное Село': 178,
#  'Кронштадт': 96,
#  'Кудрово': 173,
#  'Лодейное Поле': 20,
#  'Ломоносов': 133,
#  'Луга': 56,
#  'Любань': 8,
#  'Мурино': 34,
#  'Никольское': 93,
#  'Новая Ладога': 14,
#  'Отрадное': 80,
#  'Павловск': 38,
#  'Петергоф': 201,
#  'Пикалёво': 18,
#  'Подпорожье': 19,
#  'Приморск': 8,
#  'Приозерск': 66,
#  'Пушкин': 369,
#  'Санкт-Петербург': 15721,
#  'Светогорск': 11,
#  'Сертолово': 142,
#  'Сестрорецк': 183,
#  'Сланцы': 112,
#  'Сосновый Бор': 87,
#  'Сясьстрой': 24,
#  'Тихвин': 49,
#  'Тосно': 104,
#  'Шлиссельбург': 57,
#  'городской поселок Большая Ижора': 16,
#  'городской поселок Янино-1': 7,
#  'городской посёлок Будогощь': 4,
# ...

# %%
nan_ratio('locality_name')
# Out:
# Пропущено 0.2% значений

# %% [markdown]
# _Есть дубликаты, е и ё внесли в таблицу судя по всему люди случайно. Можно заметить, что ошибки в основном в маленьких деревнях, в больших посёлках и городах названия в порядке, и соответствуют значениям, потому можно оставить 2-3 суммарно таких значения, в добавок они никак не повлияют на результаты исследования. Также очень мало пропусков, далее мы разберёмся с ними._

# %%
print ('Дубликатов в таблице:', data.duplicated().sum())
# Out:
# Дубликатов в таблице: 0

# %% [markdown]
# ##### Проверим "is_apartment"

# %%
data['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# _3 значения, 0 и NaN это скорее всего False, потому заменим далее так._

# %%
print('True:', len(data.query('is_apartment == True')))
print('False:', len(data.query('is_apartment == False')))
# Out:
# True: 50
# False: 2725

# %% [markdown]
# ##### Проверим столбец ceiling_height

# %%
print('Потолки ниже 2х метров:', len(data.query('ceiling_height <= 2')))
print('Потолки выше 5 метров:', len(data.query('ceiling_height > 5')))
data['ceiling_height'].describe()
# Out:
# Потолки ниже 2х метров: 14
# Потолки выше 5 метров: 36
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
nan_ratio('ceiling_height')
# Out:
# Пропущено 38.8% значений

# %% [markdown]
# _Далее изменим эти значения на медиану по столбцу, и разберёмся с аномалиями._

# %% [markdown]
# ##### Столбец days_exposition

# %%
nan_ratio('days_exposition')
# Out:
# Пропущено 13.4% значений

# %%
data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data[data['days_exposition'].isnull()].head(5)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0  2019-03-07T00:00:00      3
# 7              5   7915000.0        71.6  2019-04-18T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
# 45            17   5200000.0        50.6  2018-12-02T00:00:00      2
# 46            17   6600000.0        52.1  2019-01-31T00:00:00      2
#
#     ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0             2.70          16.0         51.0      8          NaN   False
# 7              NaN          24.0          NaN     22          NaN   False
# 44             NaN          22.0          NaN      3          NaN   False
# 45            2.65           9.0         30.3      7          NaN   False
# 46            2.60          24.0         29.7      9          NaN   False
#
#     open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# _days_exposition по всей видимости, есть значения которые по той или иной причине не были записаны (Точно не человеческий фактор, и не похоже на ошибку записи, тогда бы было много нетипичных значений н-р отрицательных), и в системе они ещё числятся "открытыми", возможно это ещё непроданные квартиры. Удалив данным, мы можем потерять много нужной информации для исследования, и сгруппировать не видится возможным, потому оставим столбец как есть._

# %% [markdown]
# ##### Столбец rooms

# %%
print('Количество студий:', len(data.query('rooms == 0')))
# Out:
# Количество студий: 197

# %% [markdown]
# ##### Столбец cityCenters_nearest

# %%
round(len(data[(data['locality_name'] == 'Санкт-Петербург') & (data['cityCenters_nearest'].isna())]) / len(data.reset_index(drop=True).query('locality_name == "Санкт-Петербург"')) * 100, 3)
# Out:
# 0.388

# %% [markdown]
# _Всего 0.3% жителей Санкт-Петербурга не указали расстояние до центра. По всей видимости, остальные пропуски связаны с тем, что программа пока плохо справляется с указанием расстояния до центра в деревнях, и т.д. Так как заполнить пропуски будет проблематично и трудоемко, мы оставим этот столбец таким, какой он есть, на результаты исследования он не повлияет._

# %% [markdown]
# ##### Столбец floors_total и locality_name

# %%
nan_ratio('floors_total')
# Out:
# Пропущено 0.4% значений

# %%
nan_ratio('locality_name')
# Out:
# Пропущено 0.2% значений

# %% [markdown]
# Немного пропусков, можно в этих столбцах, их можно просто удалить, так как всего этажей и название населённого пункта мы заполнить на основе других столбцов не можем.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Нужно изменить тип float на int в столбцах:
#
# - **last_price** - Сменим тип данных.
# - **rooms** - Значение в 0 комнат оставим как есть, по всей видимости - это студии. Сменим тип данных.
# - **floors_total и locality_name** - Сменим тип данных в floors_total. Удалим недостающие значения. Пропуски связаны с тем, что возможно это не обязательные к заполнению параментры.
# - **balcony** - Сменим тип данных, также сменим отсутствующие данные на 0 балконов. По всей видимости, люди у которых нет балкона не заполняли, либо не указывали эти данные.
# - **airports_nearest и cityCenters_nearest** - cityCenters_nearest Переименуем столбец. Оставим данные без изменений. Данные рассчитывала система, возможно, если в определённом радиусе не находились аэропорты, либо в саму систему не был внесена центральная точка населённого пункта, то данные заполнялись пропусками.
# - **parks_around3000, parks_nearest, ponds_around3000, ponds_nearest** - оставим как есть, ибо точные данные не сильно повлияют на результаты исследования. Пропуски связаны по аналогии с airports_nearest и cityCenters_nearest
# - **ceiling_height** - Сменим NaN на медиану по столбцу. Разберёмся с аномалиями. Пропуски связаны возможно с тем, что не все заполняют эту информацию, либо точно не знают высоту потолков
#
# Другие изменения:
#
# - **first_day_exposition** - Привести данные в удобочитаемый вид (даты).
# - **is_apartment** - Сменим на bool. Видимо, там где "0" - это не аппартаменты. Причиной пропусков может быть то, что не все люди знают разницу апартаментами и квартирами, и люди просто пропускали этот параметр при заполнении формы.
# - **living_area** и **kitchen_area** - Сменим NaN на медиану по столбцу. Пропуски связаны скорее всего с тем, что люди не знают точную жилую площадь и площадь кухни, и оставляют пустыми эти данные.
# - **days_exposition** - Заменить данные средним, или медианой будет не совсем правильным решением, но и сгруппировать по какому-либо столбцу также не видится возможным. Потому оставим пропуски как есть, далее будем учитывать этот момент при анализе данных.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Переименуем и удалим ненужные строки:

# %%
# Переименуем столбец.
data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest'})

# Удалим строки и приведём индексацию в порядок.
data.dropna(subset=['floors_total', 'locality_name'], inplace=True)
data = data.reset_index(drop=True)

data.info()
data.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        14481 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               12090 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# _Успешно!_

# %% [markdown]
# ### rooms, living_area и kitchen_area (группировка)

# %%
# Разберёмся с rooms, living_area и kitchen_area сгруппируем по общей площади.
grp = data.groupby(['total_area'])
data['living_area'] = grp.living_area.apply(lambda x: x.fillna(x.median()))
data['kitchen_area'] = grp.kitchen_area.apply(lambda x: x.fillna(x.median()))

data.info()
display(data.head(5))

print('living_area:')
nan_ratio('living_area')
print('kitchen_area:')
nan_ratio('kitchen_area')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        14481 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23432 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23380 non-null  float64
#  13  balcony               12090 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# _Успешно!_

# %% [markdown]
# ### ceiling_height (медиана)

# %%
# ceiling_height заменим медианой:
data['ceiling_height'].fillna(data['ceiling_height'].median(), inplace=True)

display(data['ceiling_height'].describe())
data.info()
# Out:
# count    23565.000000
# mean         2.724530
# std          0.991026
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23432 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          2760 non-null   object
# ...

# %% [markdown]
# ### Медиана остальных столбцов:

# %%
# Не всем значениям удалось применить группировку. Так как значений не слишком много, можно просто заменить медианой.
print('До изменений:', len(data.query('total_area < (living_area + kitchen_area)')))
data['living_area'].fillna(data['living_area'].median(), inplace=True)
data['kitchen_area'].fillna(data['kitchen_area'].median(), inplace=True)

print('После изменений:', len(data.query('total_area < (living_area + kitchen_area)')))
data.info()
data.head(5)
# Out:
# До изменений: 120
# После изменений: 234
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               12090 non-null  float64
# ...

# %% [markdown]
# _Видим что у нас явных 234 аномальных значения, на этапе фильтрации мы ещё вернёмся к ним_

# %% [markdown]
# ### balcony

# %%
# balcony сменим NaN на 0:
data['balcony'] = data['balcony'].fillna(0)
data['balcony'] = data['balcony'].astype(int)

data.info()
display(data.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# _Успешно!_

# %% [markdown]
# ### is_apartment

# %%
# is_apartment и сменим 0 и NaN на False:
data['is_apartment'] = data['is_apartment'].fillna(0)
data['is_apartment'] = data['is_apartment'].astype(bool)

data.info()
print()
display(data.query('is_apartment == True').head(5))
print('True:', len(data.query('is_apartment == True')))
print('False:', len(data.query('is_apartment == False')))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# _Боялся что можем потерять "True" строки, потому отдельно проверили, всё ли в порядке :)_

# %% [markdown]
# ### Смена типов данных:

# %%
# Сменим тип данных:
data['last_price'] = data['last_price'].astype(int)
data['floors_total'] = data['floors_total'].astype(int)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# _Тип данных изменём успешно!_

# %%
# Заменим тип данных first_day_exposition на datetime
data['first_day_exposition'] = pd.to_datetime(
    data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

data.info()
data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# _Преобразовали datatime_

# %%
data['total_images'] = data['total_images'].astype('int32')
data['last_price'] = data['last_price'].astype('int32')
data['total_area'] = data['total_area'].astype('float32')
data['rooms'] = data['rooms'].astype('int32')
data['ceiling_height'] = data['ceiling_height'].astype('float32')
data['floors_total'] = data['floors_total'].astype('int32')
data['living_area'] = data['living_area'].astype('float32')
data['floor'] = data['floor'].astype('int32')
data['kitchen_area'] = data['kitchen_area'].astype('float32')
data['balcony'] = data['balcony'].astype('int32')
data['airports_nearest'] = data['airports_nearest'].astype('float32')
data['city_centers_nearest'] = data['city_centers_nearest'].astype('float32')
data['parks_around3000'] = data['parks_around3000'].astype('float32')
data['parks_nearest'] = data['parks_nearest'].astype('float32')
data['ponds_around3000'] = data['ponds_around3000'].astype('float32')
data['ponds_nearest'] = data['ponds_nearest'].astype('float32')
data['days_exposition'] = data['days_exposition'].astype('float32')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int32
#  1   last_price            23565 non-null  int32
#  2   total_area            23565 non-null  float32
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int32
#  5   ceiling_height        23565 non-null  float32
#  6   floors_total          23565 non-null  int32
#  7   living_area           23565 non-null  float32
#  8   floor                 23565 non-null  int32
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float32
#  13  balcony               23565 non-null  int32
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# __Вывод:__
#
# - Пропуски в важных для исследования столбцах видимо всё-же связаны с тем, что они не были обязательны к заполнению, возможно, стоит пересмотреть политику заполнения формы, и сделать больше параметров обязательными.
# - После преобразования, можно заметить что использование памяти снизилось с 3.5 МБ до 2 МБ, что на больших данных очень хорошо скажется на производительности таблицы.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# _Рассчитаем цену квадратного метра:_

# %%
data['price_per_sqm'] = round(data['last_price'] / data['total_area'], 1)
data['price_per_sqm'] = data['price_per_sqm'].astype(int)

data['price_per_sqm'].describe()
# Out:
# count    2.356500e+04
# mean     9.940542e+04
# std      5.038944e+04
# min      1.110000e+02
# 25%      7.656600e+04
# 50%      9.500000e+04
# 75%      1.142130e+05
# max      1.907500e+06
# Name: price_per_sqm, dtype: float64

# %% [markdown]
# _День недели, месяц и год публикации объявления:_

# %%
data['weekday'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int32
#  1   last_price            23565 non-null  int32
#  2   total_area            23565 non-null  float32
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int32
#  5   ceiling_height        23565 non-null  float32
#  6   floors_total          23565 non-null  int32
#  7   living_area           23565 non-null  float32
#  8   floor                 23565 non-null  int32
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float32
#  13  balcony               23565 non-null  int32
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# _Этаж квартиры - первый, последний, другой:_

# %%
# Напишем функцию, которая будет принимать значения этажа, и возвращать нужные варианты.
def find(row):
    first_floor = row['floor']
    last_floor = row['floors_total']
    if first_floor == 1:
        return 'Первый этаж'
    if last_floor == first_floor:
        return 'Последний этаж'
    return 'Другой этаж'


# Применим фукнцию
data['floor_category'] = data.apply(find, axis=1)

data.info()
data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int32
#  1   last_price            23565 non-null  int32
#  2   total_area            23565 non-null  float32
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int32
#  5   ceiling_height        23565 non-null  float32
#  6   floors_total          23565 non-null  int32
#  7   living_area           23565 non-null  float32
#  8   floor                 23565 non-null  int32
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float32
#  13  balcony               23565 non-null  int32
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# _Cоотношение жилой и общей площади, а также отношение площади кухни к общей:_

# %%
data['living_ratio'] = round(data['living_area'] / data['total_area'], 3)
data['kitchen_ratio'] = round(data['kitchen_area'] / data['total_area'], 3)

data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000  108.000000           2019-03-07      3
# 1             7     3350000   40.400002           2018-12-04      1
# 2            10     5196000   56.000000           2015-08-20      2
# 3             0    64900000  159.000000           2015-07-24      3
# 4             2    10000000  100.000000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16    51.000000      8         False   False
# 1            2.65            11    18.600000      1         False   False
# 2            2.65             5    34.299999      4         False   False
# 3            2.65            14    95.000000      9         False   False
# 4            3.03            14    32.000000     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# _Столбец с расстоянием до центра в км._

# %%
data['center_km'] = data['city_centers_nearest'] / 1000

#Приведём нетипичное значение, дабы далее было удобно его вычислять.
data['center_km'] = data['center_km'].fillna(111)
data['center_km'] = data['center_km'].astype(int)

# Сменим тип данных:
data['price_per_sqm'] = data['price_per_sqm'].astype('int32')
data['weekday'] = data['weekday'].astype('int32')
data['month'] = data['month'].astype('int32')
data['year'] = data['year'].astype('int32')
data['living_ratio'] = data['living_ratio'].astype('float32')
data['kitchen_ratio'] = data['kitchen_ratio'].astype('float32')
data['center_km'] = data['center_km'].astype('int32')


display(data.head(5))
data.info()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000  108.000000           2019-03-07      3
# 1             7     3350000   40.400002           2018-12-04      1
# 2            10     5196000   56.000000           2015-08-20      2
# 3             0    64900000  159.000000           2015-07-24      3
# 4             2    10000000  100.000000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16    51.000000      8         False   False
# 1            2.65            11    18.600000      1         False   False
# 2            2.65             5    34.299999      4         False   False
# 3            2.65            14    95.000000      9         False   False
# 4            3.03            14    32.000000     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучим параметры: площадь, цена, число комнат, высота потолков.

# %% [markdown]
# #### Автоматизируем процесс, напишем функции

# %%
# Функция для гистограммы.
def col_hist(col, xmin, xmax):
    data[col].hist(bins=50, range=(xmin, xmax))

# %%
# Функция для диаграммы размаха.
def col_boxplot(col, ymin, ymax):
    plt.ylim(ymin, ymax)
    data.boxplot(col)

# %% [markdown]
# #### Площадь (total_area)

# %%
print('Значения выходящие за рамки графика:',
      len(data.query('total_area > 350')))
col_hist('total_area', 0, 350)
# Out:
# Значения выходящие за рамки графика: 41

# %%
print('Значения выходящие за рамки графика:',
      len(data.query('total_area > 150')))
data['total_area'].hist(bins=90, range=(0, 150), figsize=(12,7))
# Out:
# Значения выходящие за рамки графика: 561
# <AxesSubplot:>

# %%
col_boxplot('total_area', -10, 250)
data['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.322979
# std         35.657131
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.699997
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# __Выводы по площади:__
#
# - Медиана по площади: 52 км.м
# - Больше всего квартир в диапазоне от 40 - 69 кв.м.
# - Границы аномалий начинаются примерно у 15 кв.м, и заканчивается на 120 кв.м.

# %% [markdown]
# #### Цена (last_price)

# %%
print('Значения выходящие за рамки графика:',
      len(data.query('last_price > 25000000')))
col_hist('last_price', 0, 25000000)
# Out:
# Значения выходящие за рамки графика: 463

# %%
print('Значения выходящие за рамки графика:',
      len(data.query('last_price > 9500000')))
data['last_price'].hist(bins=60, range=(100000, 9500000), figsize=(12,7))
# Out:
# Значения выходящие за рамки графика: 3002
# <AxesSubplot:>

# %%
data['last_price'].hist(bins=60, range=(0, 500000), figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
data['last_price'].hist(bins=60, range=(0, 5000000), figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
data['last_price'].hist(bins=60, range=(10000000, 12000000), figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
col_boxplot('last_price', -1000000, 15000000)
data['last_price'].describe()
# Out:
# count    2.356500e+04
# mean     6.540058e+06
# std      1.091093e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.646000e+06
# 75%      6.790000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# __Выводы по цене:__
#
# - Медиана цены: 4.6 млн.
# - Больше всего квартир в диапазоне с 3.4 до 6.7 млн.
# - Нормальные значения находятся от 420 тыс. до 11.5 млн.

# %% [markdown]
# #### Число комнат (rooms)

# %%
print('Значения выходящие за рамки графика:', len(data.query('rooms > 6')))
data['rooms'].hist(bins=6, range=(0, 6), figsize=(10,5))
plt.show()
# Out:
# Значения выходящие за рамки графика: 90

# %%
col_boxplot('rooms', -0.5, 7)
data['rooms'].describe()
# Out:
# count    23565.000000
# mean         2.070656
# std          1.078591
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# __Промежуточные выводы:__
#
# - Медианой по кол-ву комнат принято считать 2ки
# - Совсмем немного студий
# - Больше всего от 1 до 3-х комнатных квартир.
# - Нормальными значениями будут от 0 до 6 комнат

# %% [markdown]
# #### Высота потолков (ceiling_height)

# %%
print('Значения выходящие за рамки графика:',
      len(data.query('ceiling_height > 5')))
data['ceiling_height'].hist(bins=15, range=(2, 5))
plt.show()
# Out:
# Значения выходящие за рамки графика: 36

# %%
print('Значения выходящие за рамки графика:',
      len(data.query('ceiling_height > 3')))
data['ceiling_height'].hist(bins=30, range=(2.2, 3), figsize=(12,7))
# Out:
# Значения выходящие за рамки графика: 824
# <AxesSubplot:>

# %%
data['ceiling_height'].hist(bins=20, range=(3, 4), figsize=(12,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# _После 3.6 уже очень мало значений, но оставим до 4м потолки включительно, так как в редких случаях бывают и такие квартиры_

# %%
col_boxplot('ceiling_height', 2, 4)
data['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.724316
# std          0.991057
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# __Выводы по высоте потолков:__
#
# - Медианой будет: 2.65м.
# - Больше всего квартир с высотой от 2.6м. до 2.7м.
# - Нормальными будут значения: от 2.2м. до 4м.

# %% [markdown]
# ### Изучим время продажи квартиры:

# %%
print('Значения выходящие за рамки графика:',
      len(data.query('days_exposition > 1400')))
col_hist('days_exposition', 1, 1400)
# Out:
# Значения выходящие за рамки графика: 19

# %%
data['days_exposition'].hist(bins=90, range=(100, 900), figsize=(12,7))
plt.show()

# %% [markdown]
# _Сильный спад начинается в период с 200 до 300 дней_

# %%
data['days_exposition'].hist(bins=100, range=(1, 100), figsize=(12,7))
plt.show()

# %% [markdown]
# _Можно заметить пики продаж квартир в районе 45 дней и 60. В остальном пики держатся в районе 100-200 продаж. Скорее всего именно такая скорость продаж связана с одобрением ипотеки, так как подавляющее число квартир покупается в ипотеку, нужно некоторое время чтобы её одобрили, разницей в 45 и 60 можно считать разное время одобрения в банках_

# %%
data['days_exposition'].hist(bins=20, range=(1, 20), figsize=(12,7))
plt.show()

# %% [markdown]
# _Первый пик приходится на 7 день, потому можно считать это быстрой продажей_

# %%
data['days_exposition'].hist(bins=90, range=(200, 1500), figsize=(12,7))
plt.show()

# %% [markdown]
# _После 450 дней продажи идут очень медленно, потому возьмём это значение_

# %%
col_boxplot('days_exposition', -30, 600)
data['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741394
# std        219.734482
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# __Выводы по времени продажи квартир:__
#
# - Медиана по скорости продажи будет 95 дней.
# - Больше всего значений в периоде от 45 до 231 дней.
# - После 250 дней продажи идут значительно хуже.
# - Если успели продать квартиру за 7 дней, можно считать что продажа была быстрой.
# - Если квартира продаётся больше 450 дней, продажу можно считать долгой.
# - Максимальное количество дней: 1580.
#
# Также, уберём редкие и выбивающиеся значения:

# %% [markdown]
# #### Применим фильтрацию:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int32
#  1   last_price            23565 non-null  int32
#  2   total_area            23565 non-null  float32
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int32
#  5   ceiling_height        23565 non-null  float32
#  6   floors_total          23565 non-null  int32
#  7   living_area           23565 non-null  float32
#  8   floor                 23565 non-null  int32
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float32
#  13  balcony               23565 non-null  int32
#  14  locality_name         23565 non-null  object
# ...

# %%
#Отсортируем таблицу
data = data.query('ceiling_height >= 2.2 and ceiling_height <= 4')
data = data.query('total_area >= 15 and total_area <= 120')
data = data.query('last_price > 420000 and last_price <= 11500000')
data = data.query('rooms < 6')

# Отфильтруем аномалии:
data = data.query('total_area >= (living_area + kitchen_area)')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21050 entries, 1 to 23564
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          21050 non-null  int32
#  1   last_price            21050 non-null  int32
#  2   total_area            21050 non-null  float32
#  3   first_day_exposition  21050 non-null  datetime64[ns]
#  4   rooms                 21050 non-null  int32
#  5   ceiling_height        21050 non-null  float32
#  6   floors_total          21050 non-null  int32
#  7   living_area           21050 non-null  float32
#  8   floor                 21050 non-null  int32
#  9   is_apartment          21050 non-null  bool
#  10  studio                21050 non-null  bool
#  11  open_plan             21050 non-null  bool
#  12  kitchen_area          21050 non-null  float32
#  13  balcony               21050 non-null  int32
#  14  locality_name         21050 non-null  object
# ...

# %% [markdown]
# _От общего датасета осталось 90% после небольших преобразований, но качество данных сейчас будет явно выше._

# %% [markdown]
# ### Проведём изучение:
# Какие факторы больше всего влияют на стоимость квартиры:
#
# - Зависит ли цена от площади, числа комнат, удалённости от центра.
# - Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.
# - Зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# #### Цена от площади, числа комнат, удалённости от центра:

# %%
# Цена от площади:
data.pivot_table(index='total_area', values='last_price').plot(
    grid=True, style='o', figsize=(5, 5), alpha=0.5)
plt.show()

# Цена за квадрат от площади:
data.pivot_table(index='total_area', values='price_per_sqm').plot(
    grid=True, style='o', figsize=(10, 8), alpha=0.5)
plt.show()

print('Корреляция цены к площади:', '\n',
      data['last_price'].corr(data['total_area']))
print('Корреляция за квадрат от площади:', '\n',
      data['total_area'].corr(data['price_per_sqm']))
# Out:
# Корреляция цены к площади:
#  0.6903212075945119
# Корреляция за квадрат от площади:
#  -0.08412278216337905

# %%
# Цена от числа комнат:
data.pivot_table(index='rooms', values='last_price').plot(
    grid=True, style='o-', figsize=(7, 6))
plt.show()

# Цена за квадрат от комнат:
data.pivot_table(index='rooms', values='price_per_sqm').plot(
    grid=True, style='o-', figsize=(5, 5))
plt.show()

print('Корреляция цены к комнатам:', '\n',
      data['last_price'].corr(data["rooms"]))
print('Корреляция за квадрат от комнат:', '\n',
      data['rooms'].corr(data["price_per_sqm"]))
# Out:
# Корреляция цены к комнатам:
#  0.4313319713119954
# Корреляция за квадрат от комнат:
#  -0.23512791895893184

# %%
# Зависимость цены от удалённости от центра

data.pivot_table(index='city_centers_nearest',
                 values='last_price').plot(grid=True, style='o', figsize=(5, 5), alpha=0.4)
plt.show()

data.pivot_table(index='center_km', values='last_price',
                 aggfunc='median').plot(grid=True, style='o-', figsize=(9, 5))
plt.show()

print('Корреляция цены к удалённости от центра:', '\n',
      data['city_centers_nearest'].corr(data['last_price']))
# Out:
# Корреляция цены к удалённости от центра:
#  -0.34638937007383064

# %% [markdown]
# __Вывод:__
#
# - Цена на квартиру напрямую зависит от её площади: чем больше площадь, тем выше цена. (Коэф. Пирсона = 0.6, что указывает на сильную корреляцию)
# - Цена на квартиру также зависит от числа комнат: чем больше комнат, тем дороже цена квартиры (Коэф. Пирсона = 0.4). Однако, также прослеживается небольшая взаимосвязь от количества комнат и цену за квадратный метр: Выгоднее покупать 3-5 комнатные квартиры, чем 1-ки или 2-ки (Коэф. Пирсона = -0.2, что хоть и указывает на слабую отрицательную корреляцию, но в жизни эти данные выглядят логично)
# - Расстояние до центра также влияет на стоимость квартиры, что логично(Чем дальше квартира от центра, тем дешевле она стоит, хотя график получился немного скачкообразным). (Коэф. Пирсона = -0.34, что указывает на слабую корреляцию. Однако можно заметить скопления на графике, что указывает на небольшую взаимосвязь)

# %% [markdown]
# #### Цены от того, на каком этаже расположена квартира:

# %%
# Зависимость цены от этажа

data.groupby('floor_category')['last_price'].median().plot(
    x='floor_category', y='last_price', kind='bar')
plt.show()

# %% [markdown]
# __Вывод:__
#
# - Прямой взаимосвязи в цене от этажа не было замечено, однако квартиры на первом и последнем этаже продают обычно по более низкой цене, чем квартиры на других этажах, скорее всего это связано с количеством объявлений: в 5ти этажке "1,5" - этажи которые вошли в наши значения, и "2,3,4" - которые вошли в категорию: другие этажи.

# %% [markdown]
# #### Зависимость от даты размещения: дня недели, месяца и года:

# %%
# Таблица по дню недели:
data.groupby('weekday')['last_price'].count().plot(
    x='weekday', y='last_price', kind='bar')
plt.show()

# Таблица по месяцу:
data.groupby('month')['last_price'].count().plot(
    x='month', y='last_price', kind='bar')
plt.show()

# Таблица по году:
data.groupby('year')['last_price'].count().plot(
    x='year', y='last_price', kind='bar')
plt.show()

# %%
# Таблица по дню недели:
data.groupby('weekday')['last_price'].median().plot(
    x='weekday', y='last_price', kind='bar', ylim=(4100000,4600000))
plt.show()

# Таблица по месяцу:
data.groupby('month')['last_price'].median().plot(
    x='month', y='last_price', kind='bar', ylim=(4100000,4600000))
plt.show()

# Таблица по году:
data.groupby('year')['last_price'].median().plot(
    x='year', y='last_price', kind='bar', ylim=(4100000,5500000))
plt.show()

# %% [markdown]
# __Вывод:__
#
# - Вторник-среда на эти дни больше всего объявлений с высокой ценой, возможно это связано с буднями, и рабочими днями, люди более активно смотрят объявления, в таких вопросах стоит также учитывать работников агентств, у которых эти дни выпадают на рабочие.
# - Понедельник, четверг и субботу-воскресенье можно считать среднее-активными, возможно это также связано с трудовыми буднями населения. Самый непродуктивный день на рынке - пятница, по всей видимости, люди в пятницу меньше остальных дней предпочитают заниматься вопросами недвижимости, обосновано это коротким рабочим днём, либо тем, что люди откладывают свои дела как правило на этот день точно сказать нельзя, но закономерность в этом прослеживается.
#
#
# - Самый "дорогой" месяц - это апрель, по всей видимости это связано с тем, что отпуски и какие-либо личные дела откладываются на другие месяца, да и в основном покупать квартиру в апреле разумнее, дабы успеть сделать ремонт и остальные прикладные дела, в т.ч и саму покупку (Как выше мы выяснили, она может занять некоторое время) в летний период, нежели в зимний.
# - Самый "дешёвый" - июнь, как выше было предположено, это также связано с бытом населения, на это месяц как правило выпадает много отпусков, и заниматься этим вопросом по всей видимости предпочитают уже ближе к ноябрю-декабрю, если не успели в апреле.
#
#
# - Можно заметить интересные закономерности: цены были выше в 2014 году, самые низкие цены были в 2016-2018г. В 2019 рынок по всей видимости стал расти, и цены опять идут вверх.
#
#
# - Таким образом: день недели или месяц если и влияют на конечную стоимость, то косвенно. Определённо стоит начать продавать квартиру в апреле, с вторника по среду, в эти дни и месяц рынок показывает также хорошую активность.

# %% [markdown]
# ### Изучим населённые пункты:
# - Выберем 10 населённых пунктов с наибольшим числом объявлений.
# - Посчитаем среднюю цену квадратного метра в этих населённых пунктах.
# - Выделим населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
# Посчитаем топ 10, кол-во объявлений и медиану
raiting = data.pivot_table(
    index='locality_name', values='price_per_sqm', aggfunc=('count', 'median'))
raiting.sort_values(by='count', ascending=False).head(10)
# Out:
#                      count    median
# locality_name
# Санкт-Петербург    13364.0  101816.5
# посёлок Мурино       485.0   84375.0
# посёлок Шушары       437.0   76666.0
# Всеволожск           386.0   65789.0
# Пушкин               335.0   98437.0
# Колпино              334.0   74723.5
# посёлок Парголово    325.0   91642.0
# Гатчина              298.0   67671.5
# деревня Кудрово      286.0   91734.5
# Выборг               228.0   58357.0

# %% [markdown]
# __Вывод:__
#
# - Больше всего квартир продают в Питере, где цена за квадрат самая высокая.
# - Далее идут по цене кв.м: Пушкино и деревня Кудрово. Выгоднее всего покупать квартиры в Выборге.

# %% [markdown]
# ### Изучим предложения квартир:
#
# - Выясним, какая область входит в центр.

# %%
# Цена за каждый км.
spb = data.query('locality_name == "Санкт-Петербург"')
spb_center = spb.pivot_table(index='center_km', values=[
                             'price_per_sqm', 'last_price'], aggfunc='median')
display(spb_center.head(10))

# График цены за км. на основе цены за кв.м.
spb.pivot_table(index='center_km',
                values='price_per_sqm').plot(grid=True, style='o-', xlim=(0, 15), figsize=(10, 5))
plt.show()

# График цены за км. на основе цены за квартиру.
spb.pivot_table(index='center_km',
                values='last_price').plot(grid=True, style='o-', xlim=(0, 15), figsize=(15, 7))
plt.show()
# Out:
#            last_price  price_per_sqm
# center_km
# 0             8500000       109031.5
# 1             8200000       111280.0
# 2             7650000       106837.0
# 3             7300000       102228.0
# 4             7500000       114532.0
# 5             7249000       116291.0
# 6             6500000       114611.5
# 7             6300000       115989.0
# 8             5800000       107599.0
# 9             4800000       103333.0

# %% [markdown]
# __Вывод:__
#
# - Можно обнаружить, что резкий спад в цене идёт после 8 км, потому оставим это значение за центральный район в Санкт-Петербурге.

# %% [markdown]
# ### Изучим центральный район:
#
# - Параметры: площадь, цена, число комнат, высота потолков в центральной районе.
# - Также выделим факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления).
# - Сделаем выводы. Отличаются ли они от общих выводов по всей базе?

# %% [markdown]
# #### Функции и обозначения:

# %%
# Центральный район
spb_center = data.query('(locality_name == "Санкт-Петербург") & (center_km <= 8)')

print('Всего квартир в центре:', len(spb_center))

# Функция для диаграммы размаха.
def spb_boxplot(col, ymin, ymax):
    plt.ylim(ymin, ymax)
    spb_center.boxplot(col)
# Out:
# Всего квартир в центре: 2838

# %% [markdown]
# #### Площадь в центре:

# %%
print('Значения выходящие за рамки графика:',
      len(spb_center.query('total_area > 120')))

spb_center['total_area'].hist(bins=50, range=(10, 120))
plt.show()
# Out:
# Значения выходящие за рамки графика: 0

# %%
spb_boxplot('total_area', 0, 130)
spb_center['total_area'].describe()
# Out:
# count    2838.000000
# mean       62.930187
# std        20.896284
# min        17.000000
# 25%        46.000000
# 50%        60.799999
# 75%        77.000000
# max       120.000000
# Name: total_area, dtype: float64

# %% [markdown]
# _Выводы по общей площади:_
#
# - Медиана по площади: 52 км.м
# - Больше всего квартир в диапазоне от 40 - 69 кв.м.
# - Границы аномалий начинаются примерно у 15 кв.м, и заканчивается на 120 кв.м.
#
# __Вывод по площади в ценре:__
#
# - Медиана по площади: 60 кв.м
# - Больше всего в центре квартир от 46 до 77 кв.м (Медиана 60 кв.м)
# - В отличии от общего датасета, можно заметить, что в центре средняя площадь квартир немного больше.

# %% [markdown]
# #### Цена в центре:

# %%
print('Значения выходящие за рамки графика:',
      len(spb_center.query('last_price > 12000000')))

spb_center['last_price'].hist(bins=50, range=(100000, 12000000))
plt.show()
# Out:
# Значения выходящие за рамки графика: 0

# %%
spb_boxplot('last_price', -500000, 13000000)
spb_center['last_price'].describe()
# Out:
# count    2.838000e+03
# mean     7.066791e+06
# std      2.144454e+06
# min      1.600000e+06
# 25%      5.410000e+06
# 50%      6.932818e+06
# 75%      8.650000e+06
# max      1.150000e+07
# Name: last_price, dtype: float64

# %% [markdown]
# _Выводы по общей цене:_
#
# - Медиана цены: 4.6 млн.
# - Больше всего квартир в диапазоне с 3.4 до 6.7 млн.
# - Нормальные значения находятся от 0 до 11 млн.
#
#
# __Вывод по цене в центре:__
#
# - Медиана цены: 6.9 млн.
# - Больше всего квартир от 5.4 до 8.6 млн.
# - Можно заметить, что в отличии от всех данных, средняя цена на квартиры в центры выше, что логично.

# %% [markdown]
# #### Число комнат в центре:

# %%
print('Значения выходящие за рамки графика:', len(spb_center.query('rooms > 6')))
spb_center['rooms'].hist(bins=10, range=(1, 6))
plt.show()
# Out:
# Значения выходящие за рамки графика: 0

# %%
spb_boxplot('rooms', 0, 7)
data['rooms'].describe()
# Out:
# count    21050.000000
# mean         1.923895
# std          0.888000
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          5.000000
# Name: rooms, dtype: float64

# %% [markdown]
# _Выводы по общей таблице:_
#
# - Медианой по кол-ву комнат принято считать 2ки
# - Больше всего от 1 до 3-х комнатных квартир.
# - Нормальными значениями будут от 0 до 6 комнат
#
# __Выводы по центру:__
#
# - Медианой по кол-ву комнат принято считать 2ки
# - Больше всего в центре от 1 до 3-х комнатных квартир.
# - Можно заметить, как в отличии от общих данных преобладают 2шки и 3шки, тогда как в общих данных больше однушек и двушек.

# %% [markdown]
# #### Высота потолков в центре:

# %%
print('Значения выходящие за рамки графика:',
      len(spb_center.query('ceiling_height > 3.2')))
spb_center['ceiling_height'].hist(bins=15, range=(2.5, 3.2), figsize=(10,7))
plt.show()
# Out:
# Значения выходящие за рамки графика: 306

# %%
spb_boxplot('ceiling_height', 2.2, 3.2)
spb_center['ceiling_height'].describe()
# Out:
# count    2838.000000
# mean        2.843427
# std         0.290544
# min         2.400000
# 25%         2.650000
# 50%         2.700000
# 75%         3.000000
# max         4.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# __Выводы по общей высоте потолков:__
#
# - Медианой будет: 2.65м.
# - Больше всего квартир с высотой от 2.6м. до 2.7м.
# - Нормальными будут значения: от 2.4м. до 2.8м.
#
#
# __Вывод по центру:__
#
# - Медианой будет: 2.7м.
# - Больше всего квартир с высотой от 2.65м. до 3м.
# - В центре виден сильный перевес в сторону 2.65м, как и в общем датасете. Однако, квартир с потолками в 3м в соотношении больше, чем в обычном датасете.

# %% [markdown]
# #### Выделим факторы, которые влияют на стоимость квартиры:
#
# - Число комнат.
# - Этаж.
# - Удалённость от центра.
# - Дата размещения объявления.

# %% [markdown]
# ##### Число комнат:

# %%
# Цена от числа комнат:
spb_center.pivot_table(index='rooms', values='last_price').plot(
    grid=True, style='o-', figsize=(7, 6))
plt.show()

# Цена за квадрат от комнат:
spb_center.pivot_table(index='rooms', values='price_per_sqm').plot(
    grid=True, style='o-', figsize=(5, 5))
plt.show()

print('Корреляция цены к комнатам:', '\n',
      spb_center['last_price'].corr(spb_center["rooms"]))
print('Корреляция за квадрат от комнат:', '\n',
      spb_center['rooms'].corr(spb_center["price_per_sqm"]))
# Out:
# Корреляция цены к комнатам:
#  0.47117301620571195
# Корреляция за квадрат от комнат:
#  -0.4971651977555006

# %% [markdown]
# __Вывод:__
#
# - Есть прямая зависимость цены от количества комнат, и обратная зависимость цены за кв.м. Т.е чем больше комнат, тем дешевле кв.м
# - В отличии от общих данных, график имеет более плавный вид, и обратная корреляция сильнее. Также в центре цены за квартиры сильно выше. Так 4-к стоит 8.5 млн, а в общем 6.2 млн.

# %% [markdown]
# ##### Этаж:

# %%
# Зависимость цены от этажа

spb_center.groupby('floor_category')['last_price'].median().plot(
    x='floor_category', y='last_price', kind='bar')
plt.show()

# %% [markdown]
# __Вывод:__
#
# - Этаж как и ранее не сильно влияет на цену, однако: первый этаж стоит как правило немного меньше, чем все остальные. Это, я думаю, также связано с удобством, и шумом в центре: на первом этаже шумнее чем на остальных
# - В отличии от общего датасета, можно наблюдать изменение цены на последний этаж, она здесь выше. Видимо, это связано с удобством, так как в городе, в частности в центре множество зданий с лифтом, и главный минус последнего этажа уже не так важен, тогда как главный плюс: отсутствие соседей сверху и меньше шума, особенно в центре :)

# %% [markdown]
# ##### Удалённость от центра.

# %%
spb_center.pivot_table(index='center_km', values='last_price',
                       aggfunc='median').plot(grid=True, style='o-', figsize=(8, 5))
plt.show()

print('Корреляция цены к удалённости от центра:', '\n',
      spb_center['city_centers_nearest'].corr(spb_center['last_price']))
# Out:
# Корреляция цены к удалённости от центра:
#  -0.25506361672111794

# %% [markdown]
# __Вывод:__
#
# - Ожидаемо, чем дальше от центра квартира, тем меньше она стоит, что подтверждает слабая отрицательная корреляция. Разница в корреляции возможно связана с количеством значений, либо их разбросом.
# - В отличии от общего графика: график менее скачкообразен, и имеет плавный вид, что даёт более обоснованные выводы.

# %% [markdown]
# ##### Зависимость от даты размещения:

# %%
# Таблица по дню недели:
spb_center.groupby('weekday')['last_price'].count().plot(
    x='weekday', y='last_price', kind='bar')
plt.show()

# Таблица по месяцу:
spb_center.groupby('month')['last_price'].count().plot(
    x='month', y='last_price', kind='bar')
plt.show()

# Таблица по году:
spb_center.groupby('year')['last_price'].count().plot(
    x='year', y='last_price', kind='bar')
plt.show()

# %%
# Таблица по дню недели:
spb_center.groupby('weekday')['last_price'].median().plot(
    x='weekday', y='last_price', kind='bar', ylim=(6000000, 7500000))
plt.show()

# Таблица по месяцу:
spb_center.groupby('month')['last_price'].median().plot(
    x='month', y='last_price', kind='bar', ylim=(6200000, 7500000))
plt.show()

# Таблица по году:
spb_center.groupby('year')['last_price'].median().plot(
    x='year', y='last_price', kind='bar', ylim=(6000000, 8000000))
plt.show()

# %% [markdown]
# __Вывод:__
#
# - Как ни странно, в центре в воскресенье продают в среднем по более высокой цене, чем в остальные дни, хоть и рынок не особо активен в воскресенье. По всей видимости, это связано с различием в графике работы, скорее всего в центре Санкт-Петербурга преобладает население, которое имеет график не привязаный к дню недели, либо "плавающий", что отчасти подтверждается довольно ровными остальными столбцами, также объявления во вторник в среднем дешевле, чем в остальные дни, но не сильно.
#
#
# - В сентябре как правило продают по более высокой цене, чем в остальные дни, хотя активность рынка не пиковая. Также цена выше в июле, возможно, это также связано с разницей в населении и их возможностями бюджета в среднем.
# - Самые "дешёвые" месяца выпадают на октябрь и декабрь, связано это с праздниками и в "боязни" что с нового года станут квартиры дороже, чем раньше, потому население старается продать по возможности именно в эти месяца точно нельзя быть уверенным.
#
#
# - График года в целом очень напоминает общий, за исключением 2014г, видимо, активность как и цена были тогда меньше, чем в годах после. Самым же "низким" оказался 2017г, что также соответствует общей таблице. Возможно, эта ситуация также связана с кризисом, либо финансовыми возможностями населения на тот момент.
#
#
# - В целом, также день недели либо месяц также косвенно влияют на конечную цену, в отличии от общей таблицы месяцы и дни по цене сильно отличаются, в центральном районе желательно продавать квартиру в сентябре или июле, в воскресенье.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Мы провели большое исследование. Сгруппировали, заполнили и доработали данные из всего датасета, добавили некоторые столбцы для удобства работы. Провели анализ данных, вот выводы, которые получилось узнать:**
#
# _! - Важный параметр_
#
# _# - Пожелание разработчикам_
#
# - !Цена на квартиру напрямую зависит от её площади: чем больше площадь, тем выше цена.
# - !Цена на квартиру также зависит от числа комнат: чем больше комнат, тем дороже цена квартиры. Выгоднее покупать 3-5 комнатные квартиры, чем 1-ки или 2-ки.
# - !Расстоянием до центра мы решили считать 8 км.
# - !Расстояние до центра также влияет на стоимость квартиры, что логично, чем ближе к центру квартира, тем дороже она стоит.
# - Прямой взаимосвязи в цене от этажа не было замечено, однако квартиры на первом и последнем этаже продают обычно по более низкой цене, чем квартиры на других этажах.
# - !В центре СПБ как правило квартиры имеют немного большую площадь, и в среднем продаются по более высокой цене, чем в общей таблице. Также стоит заметить что в центре больше двушек и трёшек, в отличии среднего по региону.
# - На рынке квартир цены были выше в 2014 году, самые низкие цены были в 2016-2018г. В 2019 рынок по всей видимости стал расти, и цены опять идут вверх. Таким образом: день недели или месяц косвенно влияют на конечную стоимость квартиры.
# - Квартиры стоит начать продавать в апреле, с вторника по среду. В центральном районе желательно продавать квартиру в сентябре или июле, в воскресенье. Именно в эти дни цены на квартиры выше, и шанс продать их по высокой цене будет больше.
# - Больше всего квартир продают в Санкт-Петербурге, где цена за кв.м самая высокая. Далее идут по цене кв.м: Пушкино и деревня Кудрово. Выгоднее всего покупать квартиры в Выборге.
# - #Возможно, стоит пересмотреть обязательные поля для заполнений, и изменить систему которая смотрит расстояние до центра города и близжайших водоёмов/аэропортов.
